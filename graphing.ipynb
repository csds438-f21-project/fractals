# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['axes.grid'] = True

# %%
# Exp 1

n = [1, 2, 4, 8, 16]
serial = 557.6516445
mp = [548.6740448,313.3043347,206.0884346,117.6600234,78.7157944]
ray = [643.0162242,371.9886137,215.2067417,126.4780838,80.57619882]
lewicki = [549.8670386,311.1263468,177.0104832,102.5623554,73.61344099]

plt.yscale('log',base=2) 
plt.hlines(y=serial, xmin=1, xmax=16, color='purple', label='serial')
plt.plot(n, mp, label='Python mp')
plt.plot(n, ray, label='Ray')
plt.plot(n, lewicki, label='Lewicki')
plt.title('Avg. Runtime of Pool Implementations for Fractal Generation')
plt.ylabel('Runtime (seconds)')
plt.xlabel('Number of processes/actors')
plt.legend(loc='lower left')
plt.show()
